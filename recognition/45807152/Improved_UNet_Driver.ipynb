# %%
import tensorflow as tf
from dataset import ISIC_Dataset
from config import *
from utility import dice_coefficient, IoU

# %%
# Image and mask file paths
data_path = "../../../ISIC_Data/ISIC-2017_Training_Data/*.jpg"
mask_path = "../../../ISIC_Data/ISIC-2017_Training_Part1_GroundTruth/*.png"

# %%
# Load data

lesion_data = ISIC_Dataset(data_path, mask_path, IMAGE_HEIGHT, IMAGE_WIDTH)

(train_x, train_y), (val_x, val_y), (test_x, test_y) = lesion_data.get_data_splits(0.8, 0.1, 0.1)

# %%
from modules import ImprovedUNet

model = ImprovedUNet(IMAGE_HEIGHT, IMAGE_WIDTH, 3, filters=16, kernel_size=(3, 3))
model.build_model(True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 16  448         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  2320        ['conv2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 16  2320        ['conv2d_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 128, 128, 16  0           ['conv2d_2[0][0]']
#                                 )
#
#  add (Add)                      (None, 128, 128, 16  0           ['conv2d[0][0]',
#                                 )                                 'dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 32)   4640        ['add[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 32)   9248        ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 32)   9248        ['conv2d_4[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_5[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 32)   0           ['conv2d_3[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 64)   18496       ['add_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 64)   36928       ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 64)   36928       ['conv2d_7[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_8[0][0]']
#
#  add_2 (Add)                    (None, 32, 32, 64)   0           ['conv2d_6[0][0]',
#                                                                   'dropout_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 128)  73856       ['add_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_10[0][0]']
#
#  dropout_3 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_11[0][0]']
#
#  add_3 (Add)                    (None, 16, 16, 128)  0           ['conv2d_9[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 256)    295168      ['add_3[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 256)    590080      ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 8, 8, 256)    590080      ['conv2d_13[0][0]']
#
#  dropout_4 (Dropout)            (None, 8, 8, 256)    0           ['conv2d_14[0][0]']
#
#  add_4 (Add)                    (None, 8, 8, 256)    0           ['conv2d_12[0][0]',
#                                                                   'dropout_4[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 256)  0           ['add_4[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 128)  295040      ['up_sampling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 16, 16, 256)  0           ['conv2d_15[0][0]',
#                                                                   'add_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 128)  295040      ['concatenate[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_16[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 128)  0          ['conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 64)   73792       ['up_sampling2d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_18[0][0]',
#                                                                   'add_2[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 64)   73792       ['concatenate_1[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 64)   36928       ['conv2d_19[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 64)  0           ['conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 32)   18464       ['up_sampling2d_3[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_22[0][0]',
#                                                                   'add_1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_2[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 32)   9248        ['conv2d_23[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 32  0          ['conv2d_24[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 16  4624        ['up_sampling2d_5[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 16)   1040        ['conv2d_20[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_26[0][0]',
#                                 )                                 'add[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 16)   528         ['conv2d_24[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 16)  0           ['conv2d_21[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 32  9248        ['concatenate_3[0][0]']
#                                 )
#
#  add_5 (Add)                    (None, 64, 64, 16)   0           ['conv2d_25[0][0]',
#                                                                   'up_sampling2d_2[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 128, 128, 16  528         ['conv2d_27[0][0]']
#                                 )
#
#  up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 16  0          ['add_5[0][0]']
#                                 )
#
#  add_6 (Add)                    (None, 128, 128, 16  0           ['conv2d_28[0][0]',
#                                 )                                 'up_sampling2d_4[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 128, 128, 2)  290         ['add_6[0][0]']
#
# ==================================================================================================
# Total params: 2,949,538
# Trainable params: 2,949,538
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model = model.model
model.compile(optimizer = tf.keras.optimizers.Adam(), loss = "binary_crossentropy", metrics = [dice_coefficient, IoU])

# %%
# Train model
history = model.fit(train_x, train_y, epochs = 90, validation_data = (val_x, val_y), batch_size = 64)
# Out:
# Epoch 1/90
# 25/25 [==============================] - 13s 149ms/step - loss: 0.4302 - dice_similarity: 0.7745 - IoU: 0.6428 - val_loss: 0.2174 - val_dice_similarity: 0.9050 - val_IoU: 0.8269
# Epoch 2/90
# 25/25 [==============================] - 3s 126ms/step - loss: 0.2523 - dice_similarity: 0.8686 - IoU: 0.7681 - val_loss: 0.2180 - val_dice_similarity: 0.8750 - val_IoU: 0.7778
# Epoch 3/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.2178 - dice_similarity: 0.8992 - IoU: 0.8174 - val_loss: 0.1496 - val_dice_similarity: 0.9457 - val_IoU: 0.8974
# Epoch 4/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.1655 - dice_similarity: 0.9304 - IoU: 0.8700 - val_loss: 0.1452 - val_dice_similarity: 0.9516 - val_IoU: 0.9082
# Epoch 5/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.1589 - dice_similarity: 0.9345 - IoU: 0.8772 - val_loss: 0.1371 - val_dice_similarity: 0.9563 - val_IoU: 0.9168
# Epoch 6/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.1352 - dice_similarity: 0.9429 - IoU: 0.8920 - val_loss: 0.1388 - val_dice_similarity: 0.9555 - val_IoU: 0.9153
# Epoch 7/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.1223 - dice_similarity: 0.9476 - IoU: 0.9005 - val_loss: 0.0965 - val_dice_similarity: 0.9641 - val_IoU: 0.9310
# Epoch 8/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.1079 - dice_similarity: 0.9533 - IoU: 0.9108 - val_loss: 0.0979 - val_dice_similarity: 0.9663 - val_IoU: 0.9352
# Epoch 9/90
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0965 - dice_similarity: 0.9583 - IoU: 0.9200 - val_loss: 0.0915 - val_dice_similarity: 0.9640 - val_IoU: 0.9307
# Epoch 10/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0936 - dice_similarity: 0.9589 - IoU: 0.9211 - val_loss: 0.0809 - val_dice_similarity: 0.9700 - val_IoU: 0.9420
# Epoch 11/90
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0899 - dice_similarity: 0.9603 - IoU: 0.9237 - val_loss: 0.0878 - val_dice_similarity: 0.9689 - val_IoU: 0.9400
# Epoch 12/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0847 - dice_similarity: 0.9619 - IoU: 0.9268 - val_loss: 0.0804 - val_dice_similarity: 0.9713 - val_IoU: 0.9444
# Epoch 13/90
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0799 - dice_similarity: 0.9637 - IoU: 0.9301 - val_loss: 0.0771 - val_dice_similarity: 0.9716 - val_IoU: 0.9449
# Epoch 14/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0836 - dice_similarity: 0.9629 - IoU: 0.9285 - val_loss: 0.0875 - val_dice_similarity: 0.9699 - val_IoU: 0.9417
# Epoch 15/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0787 - dice_similarity: 0.9642 - IoU: 0.9310 - val_loss: 0.0884 - val_dice_similarity: 0.9724 - val_IoU: 0.9466
# Epoch 16/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0737 - dice_similarity: 0.9668 - IoU: 0.9358 - val_loss: 0.0761 - val_dice_similarity: 0.9690 - val_IoU: 0.9400
# Epoch 17/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0688 - dice_similarity: 0.9688 - IoU: 0.9395 - val_loss: 0.0761 - val_dice_similarity: 0.9733 - val_IoU: 0.9483
# Epoch 18/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0637 - dice_similarity: 0.9709 - IoU: 0.9435 - val_loss: 0.0768 - val_dice_similarity: 0.9744 - val_IoU: 0.9503
# Epoch 19/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0623 - dice_similarity: 0.9710 - IoU: 0.9436 - val_loss: 0.0856 - val_dice_similarity: 0.9665 - val_IoU: 0.9356
# Epoch 20/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0677 - dice_similarity: 0.9693 - IoU: 0.9405 - val_loss: 0.0873 - val_dice_similarity: 0.9641 - val_IoU: 0.9308
# Epoch 21/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0632 - dice_similarity: 0.9708 - IoU: 0.9432 - val_loss: 0.0768 - val_dice_similarity: 0.9718 - val_IoU: 0.9454
# Epoch 22/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0577 - dice_similarity: 0.9727 - IoU: 0.9469 - val_loss: 0.0791 - val_dice_similarity: 0.9752 - val_IoU: 0.9519
# Epoch 23/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0525 - dice_similarity: 0.9749 - IoU: 0.9511 - val_loss: 0.0768 - val_dice_similarity: 0.9752 - val_IoU: 0.9518
# Epoch 24/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0509 - dice_similarity: 0.9758 - IoU: 0.9527 - val_loss: 0.0837 - val_dice_similarity: 0.9744 - val_IoU: 0.9503
# Epoch 25/90
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0500 - dice_similarity: 0.9763 - IoU: 0.9537 - val_loss: 0.0772 - val_dice_similarity: 0.9755 - val_IoU: 0.9524
# Epoch 26/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0516 - dice_similarity: 0.9754 - IoU: 0.9520 - val_loss: 0.0780 - val_dice_similarity: 0.9761 - val_IoU: 0.9535
# Epoch 27/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0478 - dice_similarity: 0.9771 - IoU: 0.9552 - val_loss: 0.0730 - val_dice_similarity: 0.9738 - val_IoU: 0.9491
# Epoch 28/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0441 - dice_similarity: 0.9787 - IoU: 0.9582 - val_loss: 0.0835 - val_dice_similarity: 0.9763 - val_IoU: 0.9539
# Epoch 29/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0430 - dice_similarity: 0.9793 - IoU: 0.9594 - val_loss: 0.0833 - val_dice_similarity: 0.9762 - val_IoU: 0.9538
# Epoch 30/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0424 - dice_similarity: 0.9795 - IoU: 0.9598 - val_loss: 0.0883 - val_dice_similarity: 0.9742 - val_IoU: 0.9499
# Epoch 31/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0408 - dice_similarity: 0.9802 - IoU: 0.9611 - val_loss: 0.0946 - val_dice_similarity: 0.9771 - val_IoU: 0.9555
# Epoch 32/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0388 - dice_similarity: 0.9811 - IoU: 0.9628 - val_loss: 0.0838 - val_dice_similarity: 0.9753 - val_IoU: 0.9520
# Epoch 33/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0370 - dice_similarity: 0.9820 - IoU: 0.9646 - val_loss: 0.0949 - val_dice_similarity: 0.9765 - val_IoU: 0.9543
# Epoch 34/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0376 - dice_similarity: 0.9817 - IoU: 0.9642 - val_loss: 0.0997 - val_dice_similarity: 0.9731 - val_IoU: 0.9479
# Epoch 35/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0356 - dice_similarity: 0.9826 - IoU: 0.9658 - val_loss: 0.0961 - val_dice_similarity: 0.9752 - val_IoU: 0.9517
# Epoch 36/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0330 - dice_similarity: 0.9839 - IoU: 0.9683 - val_loss: 0.1096 - val_dice_similarity: 0.9773 - val_IoU: 0.9557
# Epoch 37/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0335 - dice_similarity: 0.9837 - IoU: 0.9680 - val_loss: 0.1000 - val_dice_similarity: 0.9755 - val_IoU: 0.9525
# Epoch 38/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0307 - dice_similarity: 0.9850 - IoU: 0.9705 - val_loss: 0.1026 - val_dice_similarity: 0.9767 - val_IoU: 0.9546
# Epoch 39/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0291 - dice_similarity: 0.9858 - IoU: 0.9720 - val_loss: 0.1088 - val_dice_similarity: 0.9778 - val_IoU: 0.9567
# Epoch 40/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0297 - dice_similarity: 0.9855 - IoU: 0.9714 - val_loss: 0.1194 - val_dice_similarity: 0.9746 - val_IoU: 0.9507
# Epoch 41/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0286 - dice_similarity: 0.9861 - IoU: 0.9725 - val_loss: 0.1088 - val_dice_similarity: 0.9774 - val_IoU: 0.9561
# Epoch 42/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0266 - dice_similarity: 0.9871 - IoU: 0.9745 - val_loss: 0.1164 - val_dice_similarity: 0.9757 - val_IoU: 0.9527
# Epoch 43/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0260 - dice_similarity: 0.9872 - IoU: 0.9748 - val_loss: 0.1224 - val_dice_similarity: 0.9769 - val_IoU: 0.9550
# Epoch 44/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0247 - dice_similarity: 0.9880 - IoU: 0.9764 - val_loss: 0.1228 - val_dice_similarity: 0.9763 - val_IoU: 0.9539
# Epoch 45/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0239 - dice_similarity: 0.9883 - IoU: 0.9769 - val_loss: 0.1226 - val_dice_similarity: 0.9778 - val_IoU: 0.9568
# Epoch 46/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0239 - dice_similarity: 0.9884 - IoU: 0.9770 - val_loss: 0.1316 - val_dice_similarity: 0.9767 - val_IoU: 0.9547
# Epoch 47/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0254 - dice_similarity: 0.9876 - IoU: 0.9755 - val_loss: 0.1224 - val_dice_similarity: 0.9771 - val_IoU: 0.9555
# Epoch 48/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0251 - dice_similarity: 0.9878 - IoU: 0.9759 - val_loss: 0.1094 - val_dice_similarity: 0.9775 - val_IoU: 0.9562
# Epoch 49/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0238 - dice_similarity: 0.9885 - IoU: 0.9772 - val_loss: 0.1173 - val_dice_similarity: 0.9770 - val_IoU: 0.9552
# Epoch 50/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0228 - dice_similarity: 0.9889 - IoU: 0.9780 - val_loss: 0.1389 - val_dice_similarity: 0.9767 - val_IoU: 0.9547
# Epoch 51/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0221 - dice_similarity: 0.9892 - IoU: 0.9787 - val_loss: 0.1275 - val_dice_similarity: 0.9776 - val_IoU: 0.9564
# Epoch 52/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0254 - dice_similarity: 0.9876 - IoU: 0.9756 - val_loss: 0.1296 - val_dice_similarity: 0.9761 - val_IoU: 0.9536
# Epoch 53/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0228 - dice_similarity: 0.9888 - IoU: 0.9779 - val_loss: 0.1249 - val_dice_similarity: 0.9769 - val_IoU: 0.9550
# Epoch 54/90
# 25/25 [==============================] - 3s 127ms/step - loss: 0.0213 - dice_similarity: 0.9896 - IoU: 0.9795 - val_loss: 0.1366 - val_dice_similarity: 0.9774 - val_IoU: 0.9560
# Epoch 55/90
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0199 - dice_similarity: 0.9903 - IoU: 0.9807 - val_loss: 0.1433 - val_dice_similarity: 0.9777 - val_IoU: 0.9565
# Epoch 56/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0192 - dice_similarity: 0.9906 - IoU: 0.9814 - val_loss: 0.1573 - val_dice_similarity: 0.9771 - val_IoU: 0.9554
# Epoch 57/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0201 - dice_similarity: 0.9902 - IoU: 0.9805 - val_loss: 0.1397 - val_dice_similarity: 0.9775 - val_IoU: 0.9563
# Epoch 58/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0191 - dice_similarity: 0.9907 - IoU: 0.9817 - val_loss: 0.1363 - val_dice_similarity: 0.9766 - val_IoU: 0.9544
# Epoch 59/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0190 - dice_similarity: 0.9907 - IoU: 0.9816 - val_loss: 0.1449 - val_dice_similarity: 0.9771 - val_IoU: 0.9555
# Epoch 60/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0183 - dice_similarity: 0.9911 - IoU: 0.9823 - val_loss: 0.1421 - val_dice_similarity: 0.9779 - val_IoU: 0.9569
# Epoch 61/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0185 - dice_similarity: 0.9910 - IoU: 0.9822 - val_loss: 0.1635 - val_dice_similarity: 0.9775 - val_IoU: 0.9561
# Epoch 62/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0177 - dice_similarity: 0.9914 - IoU: 0.9829 - val_loss: 0.1628 - val_dice_similarity: 0.9770 - val_IoU: 0.9554
# Epoch 63/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0174 - dice_similarity: 0.9915 - IoU: 0.9832 - val_loss: 0.1601 - val_dice_similarity: 0.9777 - val_IoU: 0.9566
# Epoch 64/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0167 - dice_similarity: 0.9919 - IoU: 0.9840 - val_loss: 0.1542 - val_dice_similarity: 0.9775 - val_IoU: 0.9562
# Epoch 65/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0167 - dice_similarity: 0.9919 - IoU: 0.9839 - val_loss: 0.1662 - val_dice_similarity: 0.9778 - val_IoU: 0.9567
# Epoch 66/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0163 - dice_similarity: 0.9921 - IoU: 0.9844 - val_loss: 0.1631 - val_dice_similarity: 0.9777 - val_IoU: 0.9566
# Epoch 67/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0164 - dice_similarity: 0.9921 - IoU: 0.9843 - val_loss: 0.1682 - val_dice_similarity: 0.9759 - val_IoU: 0.9532
# Epoch 68/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0168 - dice_similarity: 0.9918 - IoU: 0.9837 - val_loss: 0.1737 - val_dice_similarity: 0.9780 - val_IoU: 0.9571
# Epoch 69/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0157 - dice_similarity: 0.9923 - IoU: 0.9848 - val_loss: 0.1640 - val_dice_similarity: 0.9782 - val_IoU: 0.9575
# Epoch 70/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0155 - dice_similarity: 0.9925 - IoU: 0.9850 - val_loss: 0.1671 - val_dice_similarity: 0.9774 - val_IoU: 0.9561
# Epoch 71/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0152 - dice_similarity: 0.9926 - IoU: 0.9852 - val_loss: 0.1747 - val_dice_similarity: 0.9780 - val_IoU: 0.9573
# Epoch 72/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0150 - dice_similarity: 0.9927 - IoU: 0.9855 - val_loss: 0.1781 - val_dice_similarity: 0.9777 - val_IoU: 0.9565
# Epoch 73/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0149 - dice_similarity: 0.9928 - IoU: 0.9856 - val_loss: 0.1642 - val_dice_similarity: 0.9787 - val_IoU: 0.9586
# Epoch 74/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0149 - dice_similarity: 0.9928 - IoU: 0.9856 - val_loss: 0.1726 - val_dice_similarity: 0.9781 - val_IoU: 0.9574
# Epoch 75/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0150 - dice_similarity: 0.9927 - IoU: 0.9855 - val_loss: 0.1680 - val_dice_similarity: 0.9776 - val_IoU: 0.9564
# Epoch 76/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0151 - dice_similarity: 0.9926 - IoU: 0.9854 - val_loss: 0.1733 - val_dice_similarity: 0.9778 - val_IoU: 0.9568
# Epoch 77/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0146 - dice_similarity: 0.9929 - IoU: 0.9859 - val_loss: 0.1735 - val_dice_similarity: 0.9782 - val_IoU: 0.9576
# Epoch 78/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0138 - dice_similarity: 0.9933 - IoU: 0.9867 - val_loss: 0.1786 - val_dice_similarity: 0.9776 - val_IoU: 0.9565
# Epoch 79/90
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0139 - dice_similarity: 0.9932 - IoU: 0.9866 - val_loss: 0.1775 - val_dice_similarity: 0.9781 - val_IoU: 0.9572
# Epoch 80/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0137 - dice_similarity: 0.9933 - IoU: 0.9868 - val_loss: 0.1931 - val_dice_similarity: 0.9783 - val_IoU: 0.9576
# Epoch 81/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0143 - dice_similarity: 0.9930 - IoU: 0.9862 - val_loss: 0.1884 - val_dice_similarity: 0.9783 - val_IoU: 0.9578
# Epoch 82/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0149 - dice_similarity: 0.9928 - IoU: 0.9857 - val_loss: 0.1542 - val_dice_similarity: 0.9782 - val_IoU: 0.9576
# Epoch 83/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0145 - dice_similarity: 0.9929 - IoU: 0.9859 - val_loss: 0.1652 - val_dice_similarity: 0.9781 - val_IoU: 0.9573
# Epoch 84/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0137 - dice_similarity: 0.9933 - IoU: 0.9868 - val_loss: 0.1872 - val_dice_similarity: 0.9779 - val_IoU: 0.9569
# Epoch 85/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0132 - dice_similarity: 0.9936 - IoU: 0.9872 - val_loss: 0.1741 - val_dice_similarity: 0.9781 - val_IoU: 0.9574
# Epoch 86/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0138 - dice_similarity: 0.9933 - IoU: 0.9867 - val_loss: 0.1915 - val_dice_similarity: 0.9778 - val_IoU: 0.9567
# Epoch 87/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0131 - dice_similarity: 0.9936 - IoU: 0.9873 - val_loss: 0.1956 - val_dice_similarity: 0.9779 - val_IoU: 0.9570
# Epoch 88/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0130 - dice_similarity: 0.9937 - IoU: 0.9875 - val_loss: 0.1929 - val_dice_similarity: 0.9769 - val_IoU: 0.9551
# Epoch 89/90
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0127 - dice_similarity: 0.9938 - IoU: 0.9878 - val_loss: 0.1895 - val_dice_similarity: 0.9787 - val_IoU: 0.9585
# Epoch 90/90
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0125 - dice_similarity: 0.9939 - IoU: 0.9880 - val_loss: 0.1984 - val_dice_similarity: 0.9775 - val_IoU: 0.9561

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plot training results
plt.figure(0)
plt.plot(history.history['loss'], label='Loss')
plt.title("Loss vs Training Epoch")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
# plt.savefig("./figures/lossVsEpoch.png")

plt.figure(1)
plt.plot(history.history['dice_coefficient'], label='Dice Coefficient')
plt.title("Dice Coefficient vs Training Epoch")
plt.xlabel('Epoch')
plt.ylabel('Dice Coeficient')
plt.legend(loc='lower right')
# plt.savefig("./figures/diceVsEpoch.png")

# IoU vs Epoch
plt.figure(2)
plt.plot(history.history['IoU'], label='IoU')
plt.title("IoU vs Training Epoch")
plt.xlabel('Epoch')
plt.ylabel('Intersection Over Union')
plt.legend(loc='lower right')
# plt.savefig("./figures/iouVsEpoch.png")

# %%
def make_prediction(model, test_x, test_y, slice=(0, 1)):
    """
    Make predictions on test data using trained model.
    
    Specify slice of test data to predict.
    """
    # Get predictions on test data from trained model
    predictions = model.predict(test_x)

    first_test = slice[0]
    last_test = slice[1]
    figure_counter = 0

    for i in range(first_test, last_test):
        plt.figure(figure_counter)
        figure_counter += 1

        fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
        # Original Image Plot
        ax1.set_title("Original Image")
        ax1.axis("off")
        ax1.imshow(test_x[i])
        # Ground Truth Mask Plot
        ax2.set_title("Ground Truth Mask")
        ax2.axis("off")
        ax2.imshow(tf.argmax(test_y[i], axis=2), cmap='gray')
        # Get metrics
        pred_dice = np.around(dice_coefficient(
            test_y[i], predictions[i]).numpy(), 3)
        pred_iou = np.around(IoU(test_y[i], predictions[i]).numpy(), 3)
        
        ax3.set_title(f"Prediction")
        ax3.axis("off")
        ax3.text(0, 150, f"DSC={str(pred_dice)}, IoU={str(pred_iou)}")
        ax3.imshow(tf.argmax(predictions[i], axis=2), cmap='gray')

        plt.savefig(f"./figures/testComparison{i}.png", bbox_inches='tight')

    return

# %%
make_prediction(model, test_x, test_y, slice=(151, 161))
# Out:
# 7/7 [==============================] - 1s 18ms/step

# %%
# Model evaluation

#Evaluate model performance
test_loss, test_dce, test_iou = model.evaluate(test_x,  test_y, verbose=2, batch_size=64)
# Out:
# 4/4 - 0s - loss: 0.2532 - dice_similarity: 0.9528 - IoU: 0.9104 - 496ms/epoch - 124ms/step
