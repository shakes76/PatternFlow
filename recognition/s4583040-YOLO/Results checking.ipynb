# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("..")

# %%
import cv2
import numpy as np
from glob import glob
from models import Yolov4

# %%
class_name_path = '../../classes.txt'

model = Yolov4(weight_path=None, 
               class_name_path=class_name_path)
model.load_model('../../checkpoint1')
# Out:
# nms iou: 0.413 score: 0.3
# C:\Users\siwan\anaconda3\envs\s4583040\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# nms iou: 0.413 score: 0.3

# %%
model.predict('../../ISIC_Images/ISIC2018_Task1-2_Training_Input_x2/ISIC_0000003.jpg', random_color=True)
# Out:
# img shape:  (384, 511, 3)
# # of bboxes: 1
#    x1  y1   x2   y2 class_name    score    w    h
# 0  69   2  196  182     lesion  0.78323  127  180
