# %%
from DCGAN import DCGAN
from image_loader import ImgLoader

# %%
IMG_SIZE = 64
TARGET_SLICE = list(range(5,10))
TARGET_SLICE
# Out:
# [5, 6, 7, 8, 9]

# %% [markdown]
# # Initialize img loader

# %%
img_loader = ImgLoader("E:\Datasets\keras_png_slices_data\keras_png_slices_train")
train_dataset = img_loader.load_to_tensor(target_slice=TARGET_SLICE,img_size=IMG_SIZE)

# %% [markdown]
# # Initialize 64*64 DCGAN and Start training

# %%
dcgan = DCGAN(IMG_SIZE)

# %%
# %%time
hist_ssim = dcgan.train(train_dataset,10000)
hist_ssim
# Out:
# Wall time: 8h 38min 5s
# [0.506667,
#  0.5352533,
#  0.57885826,
#  0.53905773,
#  0.5108956,
#  0.5857693,
#  0.5848989,
#  0.54156446,
#  0.60900307,
#  0.6180514,
#  0.59632146,
#  0.61000276,
#  0.61511827,
#  0.5806933,
#  0.5877973,
#  0.59528804,
#  0.6012719,
#  0.57195157,
#  0.5911336,
#  0.60880435,
#  0.5988767,
#  0.5972018,
#  0.613755,
#  0.61340654,
#  0.6060524,
#  0.61827266,
#  0.60800517,
#  0.60019124,
#  0.6090857,
#  0.6180469,
#  0.6215186,
#  0.60783863,
#  0.59946895,
#  0.6103656,
#  0.5871761,
#  0.61229074,
#  0.6092179,
#  0.58817595,
#  0.6163579,
#  0.59733313,
#  0.5940267,
#  0.59560746,
#  0.61482215,
#  0.62605166,
#  0.5724753,
#  0.6054809,
#  0.6052245,
#  0.6159371,
#  0.58196926,
#  0.60139984,
#  0.60700965,
#  0.6050457,
#  0.6255174,
#  0.6012694,
#  0.6288264,
#  0.60514575,
#  0.60838115,
#  0.6234385,
#  0.5974748,
#  0.5894391,
#  0.60263956,
#  0.6076581,
#  0.61583424,
#  0.61278576,
#  0.60803807,
#  0.597746,
#  0.6092894,
#  0.6163489,
#  0.5965581,
#  0.6018706,
#  0.60742384,
#  0.6061584,
#  0.5980724,
#  0.6037599,
#  0.6138853,
#  0.5964503,
#  0.5935178,
#  0.58871007,
#  0.62804395,
#  0.60561055,
#  0.606728,
#  0.6153449,
#  0.6083073,
#  0.6057044,
#  0.6176229,
#  0.6122706,
#  0.6038122,
#  0.59024954,
#  0.6019354,
#  0.62125736,
#  0.6152455,
#  0.61328495,
#  0.60264033,
#  0.6021445,
#  0.588359,
#  0.6155184,
#  0.6228931,
#  0.611809,
#  0.58382833,
#  0.60570043]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(list(range(0,10000,100)),hist_ssim)
plt.title('64*64 DCGAN')
plt.xlabel('Epoch')
plt.ylabel('SSIM')
plt.show()
