# %%
import tensorflow as tf

import os
import math
import numpy as np

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import array_to_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing import image_dataset_from_directory

from IPython.display import display
# Out:
# 2022-10-15 19:05:07.838755: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
train_dir = "/home/ling/PatternFlow/recognition/44708627_ Efficient_Sub_Pixel_CNN/dataset/train"
test_dir = "/home/ling/PatternFlow/recognition/44708627_ Efficient_Sub_Pixel_CNN/dataset/test"

# %%
crop_size = 300
upscale_factor = 3
input_size = crop_size // upscale_factor
batch_size = 8

train_ds = image_dataset_from_directory(
    train_dir,
    batch_size=batch_size,
    image_size=(crop_size, crop_size),
    validation_split=0.2,
    subset="training",
    seed=1337,
    label_mode=None,
)

valid_ds = image_dataset_from_directory(
    train_dir,
    batch_size=batch_size,
    image_size=(crop_size, crop_size),
    validation_split=0.2,
    subset="validation",
    seed=1337,
    label_mode=None,
)
# Out:
# Found 21520 files belonging to 1 classes.
# Using 17216 files for training.
# 2022-10-15 19:05:10.080382: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 19:05:10.083579: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 19:05:10.083667: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 19:05:10.083929: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-15 19:05:10.084299: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 19:05:10.084371: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 19:05:10.084417: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 19:05:10.373443: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 19:05:10.373552: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 19:05:10.373614: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 19:05:10.373694: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9814 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6
# Found 21520 files belonging to 1 classes.
# Using 4304 files for validation.

# %%
def scaling(input_image):
    input_image = input_image / 255.0
    return input_image


# Scale from (0, 255) to (0, 1)
train_ds = train_ds.map(scaling)
valid_ds = valid_ds.map(scaling)

# %%
for batch in train_ds.take(1):
    for img in batch:
        display(array_to_img(img))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
# <PIL.Image.Image image mode=RGB size=300x300>
# <PIL.Image.Image image mode=RGB size=300x300>
# <PIL.Image.Image image mode=RGB size=300x300>
# <PIL.Image.Image image mode=RGB size=300x300>
# <PIL.Image.Image image mode=RGB size=300x300>
# <PIL.Image.Image image mode=RGB size=300x300>
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
dataset = os.path.join(test_dir, "Combine")

test_img_paths = sorted(
    [
        os.path.join(dataset, fname)
        for fname in os.listdir(dataset)
        if fname.endswith(".jpeg")
    ]
)
# print(dataset)
# print(test_img_paths)

# %%
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
# input1 = mpimg.imread(test_img_paths[0])
# print(input1.shape)
# input1 = input1 / 255.0
# im = tf.image.rgb_to_yuv(input1)
# print(im.shape,len(input1.shape))

# %%
# Use TF Ops to process.
def process_input(input, input_size, upscale_factor):
    input = tf.image.rgb_to_yuv(input)
    last_dimension_axis = len(input.shape) - 1
    y, u, v = tf.split(input, 3, axis=last_dimension_axis)
    return tf.image.resize(y, [input_size, input_size], method="area")


def process_target(input):
    input = tf.image.rgb_to_yuv(input)
    print(input.shape)
    last_dimension_axis = len(input.shape) - 1
    y, u, v = tf.split(input, 3, axis=last_dimension_axis)
    print(y.shape)
    return y


train_ds = train_ds.map(
    lambda x: (process_input(x, input_size, upscale_factor), process_target(x))
)
train_ds = train_ds.prefetch(buffer_size=32)

valid_ds = valid_ds.map(
    lambda x: (process_input(x, input_size, upscale_factor), process_target(x))
)
valid_ds = valid_ds.prefetch(buffer_size=32)
# Out:
# (None, 300, 300, 3)
# (None, 300, 300, 1)
# (None, 300, 300, 3)
# (None, 300, 300, 1)

# %%
for batch in train_ds.take(1):
    for img in batch[0]:
        display(array_to_img(img))
    for img in batch[1]:
        display(array_to_img(img))
# Out:
# <PIL.Image.Image image mode=L size=100x100>
# <PIL.Image.Image image mode=L size=100x100>
# <PIL.Image.Image image mode=L size=100x100>
# <PIL.Image.Image image mode=L size=100x100>
# <PIL.Image.Image image mode=L size=100x100>
# <PIL.Image.Image image mode=L size=100x100>
# <PIL.Image.Image image mode=L size=100x100>
# <PIL.Image.Image image mode=L size=100x100>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>

# %%
def get_model(upscale_factor=3, channels=1):
    conv_args = {
        "activation": "relu",
        "kernel_initializer": "Orthogonal",
        "padding": "same",
    }
    inputs = keras.Input(shape=(None, None, channels))
    x = layers.Conv2D(64, 5, **conv_args)(inputs)
    x = layers.Conv2D(64, 3, **conv_args)(x)
    x = layers.Conv2D(32, 3, **conv_args)(x)
    x = layers.Conv2D(channels * (upscale_factor ** 2), 3, **conv_args)(x)
    outputs = tf.nn.depth_to_space(x, upscale_factor)

    return keras.Model(inputs, outputs)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import PIL


def plot_results(img, prefix, title):
    """Plot the result with zoom-in area."""
    img_array = img_to_array(img)
    img_array = img_array.astype("float32") / 255.0

    # Create a new figure with a default 111 subplot.
    fig, ax = plt.subplots()
    im = ax.imshow(img_array[::-1], origin="lower")

    plt.title(title)
    # zoom-factor: 2.0, location: upper-left
    axins = zoomed_inset_axes(ax, 2, loc=2)
    axins.imshow(img_array[::-1], origin="lower")

    # Specify the limits.
    x1, x2, y1, y2 = 50, 100, 125, 175
    # Apply the x-limits.
    axins.set_xlim(x1, x2)
    # Apply the y-limits.
    axins.set_ylim(y1, y2)

    plt.yticks(visible=False)
    plt.xticks(visible=False)

    # Make the line.
    mark_inset(ax, axins, loc1=1, loc2=3, fc="none", ec="blue")
#     plt.savefig(str(prefix) + "-" + title + ".png")
    plt.show()


def get_lowres_image(img, upscale_factor):
    """Return low-resolution image to use as model input."""
    return img.resize(
        (img.size[0] // upscale_factor, img.size[1] // upscale_factor),
        PIL.Image.BICUBIC,
    )


def upscale_image(model, img):
    """Predict the result based on input image and restore the image as RGB."""
    ycbcr = img.convert("YCbCr")
    y, cb, cr = ycbcr.split()
    y = img_to_array(y)
    y = y.astype("float32") / 255.0

    input = np.expand_dims(y, axis=0)
    out = model.predict(input)

    out_img_y = out[0]
    out_img_y *= 255.0

    # Restore the image in RGB color space.
    out_img_y = out_img_y.clip(0, 255)
    out_img_y = out_img_y.reshape((np.shape(out_img_y)[0], np.shape(out_img_y)[1]))
    out_img_y = PIL.Image.fromarray(np.uint8(out_img_y), mode="L")
    out_img_cb = cb.resize(out_img_y.size, PIL.Image.BICUBIC)
    out_img_cr = cr.resize(out_img_y.size, PIL.Image.BICUBIC)
    out_img = PIL.Image.merge("YCbCr", (out_img_y, out_img_cb, out_img_cr)).convert(
        "RGB"
    )
    return out_img

# %%
class ESPCNCallback(keras.callbacks.Callback):
    def __init__(self):
        super(ESPCNCallback, self).__init__()
        self.test_img = get_lowres_image(load_img(test_img_paths[0]), upscale_factor)

    # Store PSNR value in each epoch.
    def on_epoch_begin(self, epoch, logs=None):
        self.psnr = []

    def on_epoch_end(self, epoch, logs=None):
        print("Mean PSNR for epoch: %.2f" % (np.mean(self.psnr)))
        if epoch % 20 == 0:
            prediction = upscale_image(self.model, self.test_img)
            plot_results(prediction, "epoch-" + str(epoch), "prediction")

    def on_test_batch_end(self, batch, logs=None):
        self.psnr.append(10 * math.log10(1 / logs["loss"]))

# %%
early_stopping_callback = keras.callbacks.EarlyStopping(monitor="loss", patience=10)

checkpoint_filepath = "/tmp/checkpoint"

model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor="loss",
    mode="min",
    save_best_only=True,
)

model = get_model(upscale_factor=upscale_factor, channels=1)
model.summary()

callbacks = [ESPCNCallback(), early_stopping_callback, model_checkpoint_callback]
loss_fn = keras.losses.MeanSquaredError()
optimizer = keras.optimizers.Adam(learning_rate=0.001)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 1)]   0
#
#  conv2d (Conv2D)             (None, None, None, 64)    1664
#
#  conv2d_1 (Conv2D)           (None, None, None, 64)    36928
#
#  conv2d_2 (Conv2D)           (None, None, None, 32)    18464
#
#  conv2d_3 (Conv2D)           (None, None, None, 9)     2601
#
#  tf.nn.depth_to_space (TFOpL  (None, None, None, 1)    0
#  ambda)
#
# =================================================================
# Total params: 59,657
# Trainable params: 59,657
# Non-trainable params: 0
# _________________________________________________________________
# /tmp/ipykernel_52739/4276879471.py:41: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   PIL.Image.BICUBIC,

# %%
epochs = 100

model.compile(
    optimizer=optimizer, loss=loss_fn,
)

model.fit(
    train_ds, epochs=epochs, callbacks=callbacks, validation_data=valid_ds, verbose=2
)

# The model weights (that are considered the best) are loaded into the model.
model.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/100
# 2022-10-15 19:05:15.054634: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# Mean PSNR for epoch: 32.86
# 1/1 [==============================] - 0s 69ms/step
# /tmp/ipykernel_52739/4276879471.py:62: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   out_img_cb = cb.resize(out_img_y.size, PIL.Image.BICUBIC)
# /tmp/ipykernel_52739/4276879471.py:63: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   out_img_cr = cr.resize(out_img_y.size, PIL.Image.BICUBIC)
# 2152/2152 - 18s - loss: 8.2007e-04 - val_loss: 5.1612e-04 - 18s/epoch - 8ms/step
# Epoch 2/100
# Mean PSNR for epoch: 33.14
# 2152/2152 - 16s - loss: 5.0406e-04 - val_loss: 4.8368e-04 - 16s/epoch - 8ms/step
# Epoch 3/100
# Mean PSNR for epoch: 33.25
# 2152/2152 - 16s - loss: 4.8259e-04 - val_loss: 4.7074e-04 - 16s/epoch - 7ms/step
# Epoch 4/100
# Mean PSNR for epoch: 33.30
# 2152/2152 - 16s - loss: 4.7302e-04 - val_loss: 4.6522e-04 - 16s/epoch - 7ms/step
# Epoch 5/100
# Mean PSNR for epoch: 33.37
# 2152/2152 - 16s - loss: 4.6505e-04 - val_loss: 4.5880e-04 - 16s/epoch - 8ms/step
# Epoch 6/100
# Mean PSNR for epoch: 33.37
# 2152/2152 - 16s - loss: 4.5865e-04 - val_loss: 4.5982e-04 - 16s/epoch - 7ms/step
# Epoch 7/100
# Mean PSNR for epoch: 33.45
# 2152/2152 - 16s - loss: 4.5385e-04 - val_loss: 4.5087e-04 - 16s/epoch - 7ms/step
# Epoch 8/100
# Mean PSNR for epoch: 33.48
# 2152/2152 - 16s - loss: 4.5027e-04 - val_loss: 4.4679e-04 - 16s/epoch - 7ms/step
# Epoch 9/100
# Mean PSNR for epoch: 33.51
# 2152/2152 - 16s - loss: 4.4689e-04 - val_loss: 4.4440e-04 - 16s/epoch - 7ms/step
# Epoch 10/100
# Mean PSNR for epoch: 33.55
# 2152/2152 - 16s - loss: 4.4457e-04 - val_loss: 4.4044e-04 - 16s/epoch - 7ms/step
# Epoch 11/100
# Mean PSNR for epoch: 33.56
# 2152/2152 - 15s - loss: 4.4235e-04 - val_loss: 4.3958e-04 - 15s/epoch - 7ms/step
# Epoch 12/100
# Mean PSNR for epoch: 33.58
# 2152/2152 - 16s - loss: 4.4044e-04 - val_loss: 4.3709e-04 - 16s/epoch - 7ms/step
# Epoch 13/100
# Mean PSNR for epoch: 33.60
# 2152/2152 - 16s - loss: 4.3866e-04 - val_loss: 4.3503e-04 - 16s/epoch - 7ms/step
# Epoch 14/100
# Mean PSNR for epoch: 33.59
# 2152/2152 - 16s - loss: 4.3769e-04 - val_loss: 4.3551e-04 - 16s/epoch - 7ms/step
# Epoch 15/100
# Mean PSNR for epoch: 33.61
# 2152/2152 - 16s - loss: 4.3618e-04 - val_loss: 4.3489e-04 - 16s/epoch - 7ms/step
# Epoch 16/100
# Mean PSNR for epoch: 33.63
# 2152/2152 - 16s - loss: 4.3528e-04 - val_loss: 4.3336e-04 - 16s/epoch - 7ms/step
# Epoch 17/100
# Mean PSNR for epoch: 33.63
# 2152/2152 - 16s - loss: 4.3441e-04 - val_loss: 4.3222e-04 - 16s/epoch - 7ms/step
# Epoch 18/100
# Mean PSNR for epoch: 33.65
# 2152/2152 - 16s - loss: 4.3363e-04 - val_loss: 4.3076e-04 - 16s/epoch - 7ms/step
# Epoch 19/100
# Mean PSNR for epoch: 33.66
# 2152/2152 - 16s - loss: 4.3290e-04 - val_loss: 4.2979e-04 - 16s/epoch - 7ms/step
# Epoch 20/100
# Mean PSNR for epoch: 33.65
# 2152/2152 - 16s - loss: 4.3216e-04 - val_loss: 4.3082e-04 - 16s/epoch - 7ms/step
# Epoch 21/100
# Mean PSNR for epoch: 33.67
# 1/1 [==============================] - 0s 10ms/step
# 2152/2152 - 16s - loss: 4.3123e-04 - val_loss: 4.2935e-04 - 16s/epoch - 7ms/step
# Epoch 22/100
# Mean PSNR for epoch: 33.66
# 2152/2152 - 16s - loss: 4.3075e-04 - val_loss: 4.2933e-04 - 16s/epoch - 7ms/step
# Epoch 23/100
# Mean PSNR for epoch: 33.68
# 2152/2152 - 16s - loss: 4.3011e-04 - val_loss: 4.2775e-04 - 16s/epoch - 7ms/step
# Epoch 24/100
# Mean PSNR for epoch: 33.67
# 2152/2152 - 16s - loss: 4.2930e-04 - val_loss: 4.2816e-04 - 16s/epoch - 7ms/step
# Epoch 25/100
# Mean PSNR for epoch: 33.65
# 2152/2152 - 16s - loss: 4.2860e-04 - val_loss: 4.3155e-04 - 16s/epoch - 7ms/step
# Epoch 26/100
# Mean PSNR for epoch: 33.71
# 2152/2152 - 16s - loss: 4.2792e-04 - val_loss: 4.2502e-04 - 16s/epoch - 7ms/step
# Epoch 27/100
# Mean PSNR for epoch: 33.70
# 2152/2152 - 16s - loss: 4.2718e-04 - val_loss: 4.2517e-04 - 16s/epoch - 7ms/step
# Epoch 28/100
# Mean PSNR for epoch: 33.72
# 2152/2152 - 16s - loss: 4.2624e-04 - val_loss: 4.2339e-04 - 16s/epoch - 7ms/step
# Epoch 29/100
# Mean PSNR for epoch: 33.72
# 2152/2152 - 16s - loss: 4.2557e-04 - val_loss: 4.2376e-04 - 16s/epoch - 7ms/step
# Epoch 30/100
# Mean PSNR for epoch: 33.69
# 2152/2152 - 16s - loss: 4.2483e-04 - val_loss: 4.2619e-04 - 16s/epoch - 7ms/step
# Epoch 31/100
# Mean PSNR for epoch: 33.73
# 2152/2152 - 16s - loss: 4.2415e-04 - val_loss: 4.2206e-04 - 16s/epoch - 7ms/step
# Epoch 32/100
# Mean PSNR for epoch: 33.75
# 2152/2152 - 16s - loss: 4.2362e-04 - val_loss: 4.2134e-04 - 16s/epoch - 7ms/step
# Epoch 33/100
# Mean PSNR for epoch: 33.74
# 2152/2152 - 16s - loss: 4.2310e-04 - val_loss: 4.2261e-04 - 16s/epoch - 7ms/step
# Epoch 34/100
# Mean PSNR for epoch: 33.72
# 2152/2152 - 16s - loss: 4.2282e-04 - val_loss: 4.2348e-04 - 16s/epoch - 7ms/step
# Epoch 35/100
# Mean PSNR for epoch: 33.74
# 2152/2152 - 16s - loss: 4.2250e-04 - val_loss: 4.2156e-04 - 16s/epoch - 8ms/step
# Epoch 36/100
# Mean PSNR for epoch: 33.75
# 2152/2152 - 17s - loss: 4.2198e-04 - val_loss: 4.2044e-04 - 17s/epoch - 8ms/step
# Epoch 37/100
# Mean PSNR for epoch: 33.76
# 2152/2152 - 16s - loss: 4.2181e-04 - val_loss: 4.2041e-04 - 16s/epoch - 7ms/step
# Epoch 38/100
# Mean PSNR for epoch: 33.76
# 2152/2152 - 16s - loss: 4.2138e-04 - val_loss: 4.1954e-04 - 16s/epoch - 7ms/step
# Epoch 39/100
# Mean PSNR for epoch: 33.76
# 2152/2152 - 16s - loss: 4.2125e-04 - val_loss: 4.2050e-04 - 16s/epoch - 7ms/step
# Epoch 40/100
# Mean PSNR for epoch: 33.76
# 2152/2152 - 16s - loss: 4.2081e-04 - val_loss: 4.1967e-04 - 16s/epoch - 7ms/step
# Epoch 41/100
# Mean PSNR for epoch: 33.77
# 1/1 [==============================] - 0s 10ms/step
# 2152/2152 - 16s - loss: 4.2065e-04 - val_loss: 4.1887e-04 - 16s/epoch - 7ms/step
# Epoch 42/100
# Mean PSNR for epoch: 33.77
# 2152/2152 - 16s - loss: 4.2056e-04 - val_loss: 4.1933e-04 - 16s/epoch - 7ms/step
# Epoch 43/100
# Mean PSNR for epoch: 33.78
# 2152/2152 - 16s - loss: 4.2026e-04 - val_loss: 4.1839e-04 - 16s/epoch - 7ms/step
# Epoch 44/100
# Mean PSNR for epoch: 33.76
# 2152/2152 - 16s - loss: 4.2019e-04 - val_loss: 4.1975e-04 - 16s/epoch - 7ms/step
# Epoch 45/100
# Mean PSNR for epoch: 33.79
# 2152/2152 - 16s - loss: 4.1983e-04 - val_loss: 4.1759e-04 - 16s/epoch - 7ms/step
# Epoch 46/100
# Mean PSNR for epoch: 33.77
# 2152/2152 - 16s - loss: 4.1973e-04 - val_loss: 4.1953e-04 - 16s/epoch - 7ms/step
# Epoch 47/100
# Mean PSNR for epoch: 33.78
# 2152/2152 - 16s - loss: 4.1928e-04 - val_loss: 4.1880e-04 - 16s/epoch - 7ms/step
# Epoch 48/100
# Mean PSNR for epoch: 33.77
# 2152/2152 - 16s - loss: 4.1919e-04 - val_loss: 4.1907e-04 - 16s/epoch - 7ms/step
# Epoch 49/100
# Mean PSNR for epoch: 33.77
# 2152/2152 - 16s - loss: 4.1896e-04 - val_loss: 4.1889e-04 - 16s/epoch - 7ms/step
# Epoch 50/100
# Mean PSNR for epoch: 33.77
# 2152/2152 - 16s - loss: 4.1888e-04 - val_loss: 4.1897e-04 - 16s/epoch - 7ms/step
# Epoch 51/100
# Mean PSNR for epoch: 33.78
# 2152/2152 - 16s - loss: 4.1850e-04 - val_loss: 4.1764e-04 - 16s/epoch - 7ms/step
# Epoch 52/100
# Mean PSNR for epoch: 33.78
# 2152/2152 - 16s - loss: 4.1832e-04 - val_loss: 4.1799e-04 - 16s/epoch - 7ms/step
# Epoch 53/100
# Mean PSNR for epoch: 33.76
# 2152/2152 - 16s - loss: 4.1829e-04 - val_loss: 4.2064e-04 - 16s/epoch - 7ms/step
# Epoch 54/100
# Mean PSNR for epoch: 33.79
# 2152/2152 - 16s - loss: 4.1787e-04 - val_loss: 4.1741e-04 - 16s/epoch - 7ms/step
# Epoch 55/100
# Mean PSNR for epoch: 33.80
# 2152/2152 - 16s - loss: 4.1788e-04 - val_loss: 4.1600e-04 - 16s/epoch - 7ms/step
# Epoch 56/100
# Mean PSNR for epoch: 33.80
# 2152/2152 - 16s - loss: 4.1772e-04 - val_loss: 4.1623e-04 - 16s/epoch - 7ms/step
# Epoch 57/100
# Mean PSNR for epoch: 33.80
# 2152/2152 - 16s - loss: 4.1721e-04 - val_loss: 4.1604e-04 - 16s/epoch - 7ms/step
# Epoch 58/100
# Mean PSNR for epoch: 33.79
# 2152/2152 - 16s - loss: 4.1721e-04 - val_loss: 4.1708e-04 - 16s/epoch - 7ms/step
# Epoch 59/100
# Mean PSNR for epoch: 33.80
# 2152/2152 - 17s - loss: 4.1700e-04 - val_loss: 4.1592e-04 - 17s/epoch - 8ms/step
# Epoch 60/100
# Mean PSNR for epoch: 33.79
# 2152/2152 - 16s - loss: 4.1680e-04 - val_loss: 4.1739e-04 - 16s/epoch - 8ms/step
# Epoch 61/100
# Mean PSNR for epoch: 33.81
# 1/1 [==============================] - 0s 10ms/step
# 2152/2152 - 17s - loss: 4.1662e-04 - val_loss: 4.1548e-04 - 17s/epoch - 8ms/step
# Epoch 62/100
# Mean PSNR for epoch: 33.81
# 2152/2152 - 17s - loss: 4.1651e-04 - val_loss: 4.1518e-04 - 17s/epoch - 8ms/step
# Epoch 63/100
# Mean PSNR for epoch: 33.82
# 2152/2152 - 16s - loss: 4.1612e-04 - val_loss: 4.1503e-04 - 16s/epoch - 8ms/step
# Epoch 64/100
# Mean PSNR for epoch: 33.81
# 2152/2152 - 16s - loss: 4.1598e-04 - val_loss: 4.1490e-04 - 16s/epoch - 8ms/step
# Epoch 65/100
# Mean PSNR for epoch: 33.82
# 2152/2152 - 17s - loss: 4.1601e-04 - val_loss: 4.1469e-04 - 17s/epoch - 8ms/step
# Epoch 66/100
# Mean PSNR for epoch: 33.82
# 2152/2152 - 17s - loss: 4.1581e-04 - val_loss: 4.1404e-04 - 17s/epoch - 8ms/step
# Epoch 67/100
# Mean PSNR for epoch: 33.80
# 2152/2152 - 16s - loss: 4.1555e-04 - val_loss: 4.1594e-04 - 16s/epoch - 7ms/step
# Epoch 68/100
# Mean PSNR for epoch: 33.81
# 2152/2152 - 16s - loss: 4.1540e-04 - val_loss: 4.1487e-04 - 16s/epoch - 7ms/step
# Epoch 69/100
# Mean PSNR for epoch: 33.81
# 2152/2152 - 16s - loss: 4.1538e-04 - val_loss: 4.1539e-04 - 16s/epoch - 7ms/step
# Epoch 70/100
# Mean PSNR for epoch: 33.82
# 2152/2152 - 17s - loss: 4.1517e-04 - val_loss: 4.1396e-04 - 17s/epoch - 8ms/step
# Epoch 71/100
# Mean PSNR for epoch: 33.80
# 2152/2152 - 16s - loss: 4.1523e-04 - val_loss: 4.1601e-04 - 16s/epoch - 8ms/step
# Epoch 72/100
# Mean PSNR for epoch: 33.83
# 2152/2152 - 16s - loss: 4.1493e-04 - val_loss: 4.1344e-04 - 16s/epoch - 8ms/step
# Epoch 73/100
# Mean PSNR for epoch: 33.82
# 2152/2152 - 17s - loss: 4.1477e-04 - val_loss: 4.1437e-04 - 17s/epoch - 8ms/step
# Epoch 74/100
# Mean PSNR for epoch: 33.83
# 2152/2152 - 17s - loss: 4.1480e-04 - val_loss: 4.1364e-04 - 17s/epoch - 8ms/step
# Epoch 75/100
# Mean PSNR for epoch: 33.82
# 2152/2152 - 17s - loss: 4.1459e-04 - val_loss: 4.1417e-04 - 17s/epoch - 8ms/step
# Epoch 76/100
# Mean PSNR for epoch: 33.82
# 2152/2152 - 16s - loss: 4.1446e-04 - val_loss: 4.1380e-04 - 16s/epoch - 7ms/step
# Epoch 77/100
# Mean PSNR for epoch: 33.82
# 2152/2152 - 16s - loss: 4.1440e-04 - val_loss: 4.1409e-04 - 16s/epoch - 7ms/step
# Epoch 78/100
# Mean PSNR for epoch: 33.83
# 2152/2152 - 16s - loss: 4.1424e-04 - val_loss: 4.1422e-04 - 16s/epoch - 8ms/step
# Epoch 79/100
# Mean PSNR for epoch: 33.81
# 2152/2152 - 16s - loss: 4.1425e-04 - val_loss: 4.1536e-04 - 16s/epoch - 7ms/step
# Epoch 80/100
# Mean PSNR for epoch: 33.83
# 2152/2152 - 16s - loss: 4.1416e-04 - val_loss: 4.1305e-04 - 16s/epoch - 7ms/step
# Epoch 81/100
# Mean PSNR for epoch: 33.83
# 1/1 [==============================] - 0s 10ms/step
# 2152/2152 - 16s - loss: 4.1401e-04 - val_loss: 4.1325e-04 - 16s/epoch - 7ms/step
# Epoch 82/100
# Mean PSNR for epoch: 33.82
# 2152/2152 - 16s - loss: 4.1393e-04 - val_loss: 4.1409e-04 - 16s/epoch - 7ms/step
# Epoch 83/100
# Mean PSNR for epoch: 33.83
# 2152/2152 - 16s - loss: 4.1384e-04 - val_loss: 4.1302e-04 - 16s/epoch - 8ms/step
# Epoch 84/100
# Mean PSNR for epoch: 33.83
# 2152/2152 - 16s - loss: 4.1409e-04 - val_loss: 4.1355e-04 - 16s/epoch - 8ms/step
# Epoch 85/100
# Mean PSNR for epoch: 33.84
# 2152/2152 - 16s - loss: 4.1345e-04 - val_loss: 4.1245e-04 - 16s/epoch - 8ms/step
# Epoch 86/100
# Mean PSNR for epoch: 33.82
# 2152/2152 - 16s - loss: 4.1360e-04 - val_loss: 4.1424e-04 - 16s/epoch - 7ms/step
# Epoch 87/100
# Mean PSNR for epoch: 33.83
# 2152/2152 - 16s - loss: 4.1348e-04 - val_loss: 4.1317e-04 - 16s/epoch - 7ms/step
# Epoch 88/100
# Mean PSNR for epoch: 33.83
# 2152/2152 - 17s - loss: 4.1337e-04 - val_loss: 4.1330e-04 - 17s/epoch - 8ms/step
# Epoch 89/100
# Mean PSNR for epoch: 33.84
# 2152/2152 - 17s - loss: 4.1320e-04 - val_loss: 4.1256e-04 - 17s/epoch - 8ms/step
# Epoch 90/100
# Mean PSNR for epoch: 33.83
# 2152/2152 - 17s - loss: 4.1318e-04 - val_loss: 4.1261e-04 - 17s/epoch - 8ms/step
# Epoch 91/100
# Mean PSNR for epoch: 33.84
# 2152/2152 - 16s - loss: 4.1309e-04 - val_loss: 4.1301e-04 - 16s/epoch - 8ms/step
# Epoch 92/100
# Mean PSNR for epoch: 33.84
# 2152/2152 - 17s - loss: 4.1306e-04 - val_loss: 4.1224e-04 - 17s/epoch - 8ms/step
# Epoch 93/100
# Mean PSNR for epoch: 33.84
# 2152/2152 - 16s - loss: 4.1288e-04 - val_loss: 4.1264e-04 - 16s/epoch - 8ms/step
# Epoch 94/100
# Mean PSNR for epoch: 33.84
# 2152/2152 - 17s - loss: 4.1279e-04 - val_loss: 4.1192e-04 - 17s/epoch - 8ms/step
# Epoch 95/100
# Mean PSNR for epoch: 33.84
# 2152/2152 - 16s - loss: 4.1281e-04 - val_loss: 4.1224e-04 - 16s/epoch - 7ms/step
# Epoch 96/100
# Mean PSNR for epoch: 33.85
# 2152/2152 - 16s - loss: 4.1272e-04 - val_loss: 4.1169e-04 - 16s/epoch - 8ms/step
# Epoch 97/100
# Mean PSNR for epoch: 33.85
# 2152/2152 - 18s - loss: 4.1249e-04 - val_loss: 4.1172e-04 - 18s/epoch - 8ms/step
# Epoch 98/100
# Mean PSNR for epoch: 33.84
# 2152/2152 - 16s - loss: 4.1252e-04 - val_loss: 4.1222e-04 - 16s/epoch - 8ms/step
# Epoch 99/100
# Mean PSNR for epoch: 33.84
# 2152/2152 - 16s - loss: 4.1257e-04 - val_loss: 4.1255e-04 - 16s/epoch - 7ms/step
# Epoch 100/100
# Mean PSNR for epoch: 33.84
# 2152/2152 - 16s - loss: 4.1240e-04 - val_loss: 4.1237e-04 - 16s/epoch - 7ms/step

# %%
total_bicubic_psnr = 0.0
total_test_psnr = 0.0

for index, test_img_path in enumerate(test_img_paths[50:60]):
    img = load_img(test_img_path)
    lowres_input = get_lowres_image(img, upscale_factor)
    w = lowres_input.size[0] * upscale_factor
    h = lowres_input.size[1] * upscale_factor
    highres_img = img.resize((w, h))
    prediction = upscale_image(model, lowres_input)
    lowres_img = lowres_input.resize((w, h))
    lowres_img_arr = img_to_array(lowres_img)
    highres_img_arr = img_to_array(highres_img)
    predict_img_arr = img_to_array(prediction)
    bicubic_psnr = tf.image.psnr(lowres_img_arr, highres_img_arr, max_val=255)
    test_psnr = tf.image.psnr(predict_img_arr, highres_img_arr, max_val=255)

    total_bicubic_psnr += bicubic_psnr
    total_test_psnr += test_psnr

    print(
        "PSNR of low resolution image and high resolution image is %.4f" % bicubic_psnr
    )
    print("PSNR of predict and high resolution is %.4f" % test_psnr)
    plot_results(lowres_img, index, "lowres")
    plot_results(highres_img, index, "highres")
    plot_results(prediction, index, "prediction")

print("Avg. PSNR of lowres images is %.4f" % (total_bicubic_psnr / 10))
print("Avg. PSNR of reconstructions is %.4f" % (total_test_psnr / 10))
# Out:
# 1/1 [==============================] - 0s 12ms/step
# PSNR of low resolution image and high resolution image is 27.7257
# PSNR of predict and high resolution is 29.9991
# /tmp/ipykernel_52739/4276879471.py:41: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   PIL.Image.BICUBIC,
# /tmp/ipykernel_52739/4276879471.py:62: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   out_img_cb = cb.resize(out_img_y.size, PIL.Image.BICUBIC)
# /tmp/ipykernel_52739/4276879471.py:63: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   out_img_cr = cr.resize(out_img_y.size, PIL.Image.BICUBIC)
# 1/1 [==============================] - 0s 13ms/step
# PSNR of low resolution image and high resolution image is 28.2935
# PSNR of predict and high resolution is 30.5771
# 1/1 [==============================] - 0s 13ms/step
# PSNR of low resolution image and high resolution image is 27.6166
# PSNR of predict and high resolution is 29.8603
# 1/1 [==============================] - 0s 13ms/step
# PSNR of low resolution image and high resolution image is 27.7023
# PSNR of predict and high resolution is 29.8852
# 1/1 [==============================] - 0s 12ms/step
# PSNR of low resolution image and high resolution image is 27.7613
# PSNR of predict and high resolution is 29.7493
# 1/1 [==============================] - 0s 12ms/step
# PSNR of low resolution image and high resolution image is 27.9223
# PSNR of predict and high resolution is 29.9465
# 1/1 [==============================] - 0s 11ms/step
# PSNR of low resolution image and high resolution image is 27.7062
# PSNR of predict and high resolution is 29.7042
# 1/1 [==============================] - 0s 11ms/step
# PSNR of low resolution image and high resolution image is 27.7445
# PSNR of predict and high resolution is 29.8420
# 1/1 [==============================] - 0s 12ms/step
# PSNR of low resolution image and high resolution image is 27.4116
# PSNR of predict and high resolution is 29.5607
# 1/1 [==============================] - 0s 12ms/step
# PSNR of low resolution image and high resolution image is 27.5510
# PSNR of predict and high resolution is 29.6095
# Avg. PSNR of lowres images is 27.7435
# Avg. PSNR of reconstructions is 29.8734
