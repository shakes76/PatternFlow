# %%
import tensorflow as tf

import os
import math
import numpy as np

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import array_to_img
from tensorflow.keras.preprocessing.image import img_to_array

from IPython.display import display

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import PIL
# Out:
# 2022-10-18 08:10:58.732328: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
from ipynb.fs.full.dataset import *
from ipynb.fs.full.Untitled import *
from ipynb.fs.full.moduel import *
# Out:
# hello

# %%
train_dir = "/home/ling/PatternFlow/recognition/44708627_ Efficient_Sub_Pixel_CNN/dataset/train"
test_dir = "/home/ling/PatternFlow/recognition/44708627_ Efficient_Sub_Pixel_CNN/dataset/test"

# %%
test_img_paths = test_imgs(test_dir)
train_ds, valid_ds = setup_dataset(train_dir)
train_ds, valid_ds = dataset_preprocessing(train_ds,valid_ds)
# print(test_img_paths)
# Out:
# Found 21520 files belonging to 1 classes.
# Using 17216 files for training.
# 2022-10-18 08:10:59.835058: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 08:10:59.838376: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 08:10:59.838466: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 08:10:59.838715: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-18 08:10:59.839146: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 08:10:59.839328: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 08:10:59.839388: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 08:11:00.122824: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 08:11:00.122928: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 08:11:00.122981: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 08:11:00.123034: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9673 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6
# Found 21520 files belonging to 1 classes.
# Using 4304 files for validation.
# WARNING:tensorflow:AutoGraph could not transform <function scaling at 0x7f3915fbb8b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unexpected EOF while parsing (<unknown>, line 1)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function scaling at 0x7f3915fbb8b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unexpected EOF while parsing (<unknown>, line 1)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function dataset_preprocessing.<locals>.<lambda> at 0x7f3915d64ca0> and will run it as-is.
# Cause: could not parse the source code of <function dataset_preprocessing.<locals>.<lambda> at 0x7f3915d64ca0>: no matching AST found among candidates:
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function dataset_preprocessing.<locals>.<lambda> at 0x7f3915d64ca0> and will run it as-is.
# Cause: could not parse the source code of <function dataset_preprocessing.<locals>.<lambda> at 0x7f3915d64ca0>: no matching AST found among candidates:
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function dataset_preprocessing.<locals>.<lambda> at 0x7f3915d63430> and will run it as-is.
# Cause: could not parse the source code of <function dataset_preprocessing.<locals>.<lambda> at 0x7f3915d63430>: no matching AST found among candidates:
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function dataset_preprocessing.<locals>.<lambda> at 0x7f3915d63430> and will run it as-is.
# Cause: could not parse the source code of <function dataset_preprocessing.<locals>.<lambda> at 0x7f3915d63430>: no matching AST found among candidates:
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
for batch in train_ds.take(1):
    for img in batch[0]:
        display(array_to_img(img))
    for img in batch[1]:
        display(array_to_img(img))
# Out:
# <PIL.Image.Image image mode=L size=75x75>
# <PIL.Image.Image image mode=L size=75x75>
# <PIL.Image.Image image mode=L size=75x75>
# <PIL.Image.Image image mode=L size=75x75>
# <PIL.Image.Image image mode=L size=75x75>
# <PIL.Image.Image image mode=L size=75x75>
# <PIL.Image.Image image mode=L size=75x75>
# <PIL.Image.Image image mode=L size=75x75>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>
# <PIL.Image.Image image mode=L size=300x300>

# %%
def plot_results(img, prefix, title):
    """Plot the result with zoom-in area."""
    img_array = img_to_array(img)
    img_array = img_array.astype("float32") / 255.0

    # Create a new figure with a default 111 subplot.
    fig, ax = plt.subplots()
    im = ax.imshow(img_array[::-1], origin="lower")

    plt.title(title)
    # zoom-factor: 2.0, location: upper-left
    axins = zoomed_inset_axes(ax, 2, loc=2)
    axins.imshow(img_array[::-1], origin="lower")

    # Specify the limits.
    x1, x2, y1, y2 = 50, 100, 125, 175
    # Apply the x-limits.
    axins.set_xlim(x1, x2)
    # Apply the y-limits.
    axins.set_ylim(y1, y2)

    plt.yticks(visible=False)
    plt.xticks(visible=False)

    # Make the line.
    mark_inset(ax, axins, loc1=1, loc2=3, fc="none", ec="blue")
#     plt.savefig(str(prefix) + "-" + title + ".png")
    plt.show()


def get_lowres_image(img, upscale_factor):
    """Return low-resolution image to use as model input."""
    return img.resize(
        (img.size[0] // upscale_factor, img.size[1] // upscale_factor),
        PIL.Image.BICUBIC,
    )


def upscale_image(model, img):
    """Predict the result based on input image and restore the image as RGB."""
    ycbcr = img.convert("YCbCr")
    y, cb, cr = ycbcr.split()
    y = img_to_array(y)
    y = y.astype("float32") / 255.0

    input = np.expand_dims(y, axis=0)
    out = model.predict(input)

    out_img_y = out[0]
    out_img_y *= 255.0

    # Restore the image in RGB color space.
    out_img_y = out_img_y.clip(0, 255)
    out_img_y = out_img_y.reshape((np.shape(out_img_y)[0], np.shape(out_img_y)[1]))
    out_img_y = PIL.Image.fromarray(np.uint8(out_img_y), mode="L")
    out_img_cb = cb.resize(out_img_y.size, PIL.Image.BICUBIC)
    out_img_cr = cr.resize(out_img_y.size, PIL.Image.BICUBIC)
    out_img = PIL.Image.merge("YCbCr", (out_img_y, out_img_cb, out_img_cr)).convert(
        "RGB"
    )
    return out_img

# %%
class ESPCNCallback(keras.callbacks.Callback):
    def __init__(self):
        super(ESPCNCallback, self).__init__()
        self.test_img = get_lowres_image(load_img(test_img_paths[0]), upscale_factor)

    # Store PSNR value in each epoch.
    def on_epoch_begin(self, epoch, logs=None):
        self.psnr = []

    def on_epoch_end(self, epoch, logs=None):
        print("Mean PSNR for epoch: %.2f" % (np.mean(self.psnr)))
        if epoch % 20 == 0:
            prediction = upscale_image(self.model, self.test_img)
            plot_results(prediction, "epoch-" + str(epoch), "prediction")

    def on_test_batch_end(self, batch, logs=None):
        self.psnr.append(10 * math.log10(1 / logs["loss"]))

# %%
# Stop training when a monitored metric has stopped improving.
early_stopping_callback = keras.callbacks.EarlyStopping(monitor="loss", patience=10)

checkpoint_filepath = "/tmp/checkpoint"

# save a model or weights (in a checkpoint file) at some interval, 
# so the model or weights can be loaded later to continue the 
# training from the state saved.

model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor="loss",
    mode="min",
    save_best_only=True,
)

model = get_model(upscale_factor=upscale_factor, channels=1)
model.summary()

callbacks = [ESPCNCallback(), early_stopping_callback, model_checkpoint_callback]
loss_fn = keras.losses.MeanSquaredError()
optimizer = keras.optimizers.Adam(learning_rate=0.001)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, None, None, 1)]   0
#
#  conv2d_4 (Conv2D)           (None, None, None, 64)    1664
#
#  conv2d_5 (Conv2D)           (None, None, None, 64)    36928
#
#  conv2d_6 (Conv2D)           (None, None, None, 32)    18464
#
#  conv2d_7 (Conv2D)           (None, None, None, 16)    4624
#
#  tf.nn.depth_to_space_1 (TFO  (None, None, None, 1)    0
#  pLambda)
#
# =================================================================
# Total params: 61,680
# Trainable params: 61,680
# Non-trainable params: 0
# _________________________________________________________________
# /tmp/ipykernel_41296/64990585.py:41: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   PIL.Image.BICUBIC,

# %%
epochs = 100

model.compile(
    optimizer=optimizer, loss=loss_fn,
)

model.fit(
    train_ds, epochs=epochs, callbacks=callbacks, validation_data=valid_ds, verbose=2
)

# The model weights (that are considered the best) are loaded into the model.
model.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/100
# 2022-10-18 08:11:01.993543: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# Mean PSNR for epoch: 30.47
# 1/1 [==============================] - 0s 67ms/step
# /tmp/ipykernel_41296/64990585.py:62: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   out_img_cb = cb.resize(out_img_y.size, PIL.Image.BICUBIC)
# /tmp/ipykernel_41296/64990585.py:63: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   out_img_cr = cr.resize(out_img_y.size, PIL.Image.BICUBIC)
# 2152/2152 - 15s - loss: 0.0014 - val_loss: 8.9418e-04 - 15s/epoch - 7ms/step
# Epoch 2/100
# Mean PSNR for epoch: 30.69
# 2152/2152 - 14s - loss: 8.8042e-04 - val_loss: 8.5086e-04 - 14s/epoch - 6ms/step
# Epoch 3/100
# Mean PSNR for epoch: 30.79
# 2152/2152 - 14s - loss: 8.4704e-04 - val_loss: 8.2946e-04 - 14s/epoch - 7ms/step
# Epoch 4/100
# Mean PSNR for epoch: 30.87
# 2152/2152 - 14s - loss: 8.2981e-04 - val_loss: 8.1542e-04 - 14s/epoch - 7ms/step
# Epoch 5/100
# Mean PSNR for epoch: 30.93
# 2152/2152 - 14s - loss: 8.1677e-04 - val_loss: 8.0514e-04 - 14s/epoch - 7ms/step
# Epoch 6/100
# Mean PSNR for epoch: 30.93
# 2152/2152 - 14s - loss: 8.0635e-04 - val_loss: 8.0521e-04 - 14s/epoch - 6ms/step
# Epoch 7/100
# Mean PSNR for epoch: 31.01
# 2152/2152 - 14s - loss: 7.9796e-04 - val_loss: 7.9178e-04 - 14s/epoch - 6ms/step
# Epoch 8/100
# Mean PSNR for epoch: 31.03
# 2152/2152 - 14s - loss: 7.9013e-04 - val_loss: 7.8543e-04 - 14s/epoch - 6ms/step
# Epoch 9/100
# Mean PSNR for epoch: 31.07
# 2152/2152 - 15s - loss: 7.8497e-04 - val_loss: 7.7960e-04 - 15s/epoch - 7ms/step
# Epoch 10/100
# Mean PSNR for epoch: 31.10
# 2152/2152 - 14s - loss: 7.7967e-04 - val_loss: 7.7413e-04 - 14s/epoch - 6ms/step
# Epoch 11/100
# Mean PSNR for epoch: 31.11
# 2152/2152 - 14s - loss: 7.7540e-04 - val_loss: 7.7241e-04 - 14s/epoch - 7ms/step
# Epoch 12/100
# Mean PSNR for epoch: 31.14
# 2152/2152 - 14s - loss: 7.7115e-04 - val_loss: 7.6691e-04 - 14s/epoch - 6ms/step
# Epoch 13/100
# Mean PSNR for epoch: 31.14
# 2152/2152 - 13s - loss: 7.6811e-04 - val_loss: 7.6627e-04 - 13s/epoch - 6ms/step
# Epoch 14/100
# Mean PSNR for epoch: 31.17
# 2152/2152 - 13s - loss: 7.6533e-04 - val_loss: 7.6055e-04 - 13s/epoch - 6ms/step
# Epoch 15/100
# Mean PSNR for epoch: 31.20
# 2152/2152 - 14s - loss: 7.6203e-04 - val_loss: 7.5693e-04 - 14s/epoch - 6ms/step
# Epoch 16/100
# Mean PSNR for epoch: 31.21
# 2152/2152 - 14s - loss: 7.5994e-04 - val_loss: 7.5646e-04 - 14s/epoch - 7ms/step
# Epoch 17/100
# Mean PSNR for epoch: 31.19
# 2152/2152 - 14s - loss: 7.5715e-04 - val_loss: 7.5904e-04 - 14s/epoch - 7ms/step
# Epoch 18/100
# Mean PSNR for epoch: 31.23
# 2152/2152 - 13s - loss: 7.5517e-04 - val_loss: 7.5122e-04 - 13s/epoch - 6ms/step
# Epoch 19/100
# Mean PSNR for epoch: 31.23
# 2152/2152 - 14s - loss: 7.5322e-04 - val_loss: 7.5184e-04 - 14s/epoch - 7ms/step
# Epoch 20/100
# Mean PSNR for epoch: 31.24
# 2152/2152 - 14s - loss: 7.5158e-04 - val_loss: 7.4932e-04 - 14s/epoch - 6ms/step
# Epoch 21/100
# Mean PSNR for epoch: 31.26
# 1/1 [==============================] - 0s 10ms/step
# 2152/2152 - 14s - loss: 7.4966e-04 - val_loss: 7.4685e-04 - 14s/epoch - 6ms/step
# Epoch 22/100
# Mean PSNR for epoch: 31.27
# 2152/2152 - 14s - loss: 7.4792e-04 - val_loss: 7.4421e-04 - 14s/epoch - 6ms/step
# Epoch 23/100
# Mean PSNR for epoch: 31.27
# 2152/2152 - 14s - loss: 7.4618e-04 - val_loss: 7.4495e-04 - 14s/epoch - 7ms/step
# Epoch 24/100
# Mean PSNR for epoch: 31.28
# 2152/2152 - 14s - loss: 7.4474e-04 - val_loss: 7.4309e-04 - 14s/epoch - 6ms/step
# Epoch 25/100
# Mean PSNR for epoch: 31.30
# 2152/2152 - 14s - loss: 7.4319e-04 - val_loss: 7.4073e-04 - 14s/epoch - 7ms/step
# Epoch 26/100
# Mean PSNR for epoch: 31.31
# 2152/2152 - 14s - loss: 7.4188e-04 - val_loss: 7.3840e-04 - 14s/epoch - 7ms/step
# Epoch 27/100
# Mean PSNR for epoch: 31.31
# 2152/2152 - 14s - loss: 7.4063e-04 - val_loss: 7.3778e-04 - 14s/epoch - 7ms/step
# Epoch 28/100
# Mean PSNR for epoch: 31.32
# 2152/2152 - 14s - loss: 7.3954e-04 - val_loss: 7.3599e-04 - 14s/epoch - 7ms/step
# Epoch 29/100
# Mean PSNR for epoch: 31.32
# 2152/2152 - 15s - loss: 7.3816e-04 - val_loss: 7.3647e-04 - 15s/epoch - 7ms/step
# Epoch 30/100
# Mean PSNR for epoch: 31.33
# 2152/2152 - 14s - loss: 7.3719e-04 - val_loss: 7.3438e-04 - 14s/epoch - 7ms/step
# Epoch 31/100
# Mean PSNR for epoch: 31.33
# 2152/2152 - 14s - loss: 7.3629e-04 - val_loss: 7.3419e-04 - 14s/epoch - 6ms/step
# Epoch 32/100
# Mean PSNR for epoch: 31.34
# 2152/2152 - 14s - loss: 7.3501e-04 - val_loss: 7.3419e-04 - 14s/epoch - 6ms/step
# Epoch 33/100
# Mean PSNR for epoch: 31.36
# 2152/2152 - 14s - loss: 7.3405e-04 - val_loss: 7.3054e-04 - 14s/epoch - 7ms/step
# Epoch 34/100
# Mean PSNR for epoch: 31.35
# 2152/2152 - 14s - loss: 7.3278e-04 - val_loss: 7.3055e-04 - 14s/epoch - 6ms/step
# Epoch 35/100
# Mean PSNR for epoch: 31.37
# 2152/2152 - 14s - loss: 7.3190e-04 - val_loss: 7.2749e-04 - 14s/epoch - 7ms/step
# Epoch 36/100
# Mean PSNR for epoch: 31.37
# 2152/2152 - 14s - loss: 7.3112e-04 - val_loss: 7.2853e-04 - 14s/epoch - 6ms/step
# Epoch 37/100
# Mean PSNR for epoch: 31.37
# 2152/2152 - 14s - loss: 7.3019e-04 - val_loss: 7.2718e-04 - 14s/epoch - 7ms/step
# Epoch 38/100
# Mean PSNR for epoch: 31.37
# 2152/2152 - 14s - loss: 7.2944e-04 - val_loss: 7.2727e-04 - 14s/epoch - 7ms/step
# Epoch 39/100
# Mean PSNR for epoch: 31.39
# 2152/2152 - 14s - loss: 7.2870e-04 - val_loss: 7.2556e-04 - 14s/epoch - 7ms/step
# Epoch 40/100
# Mean PSNR for epoch: 31.37
# 2152/2152 - 14s - loss: 7.2815e-04 - val_loss: 7.2831e-04 - 14s/epoch - 7ms/step
# Epoch 41/100
# Mean PSNR for epoch: 31.38
# 1/1 [==============================] - 0s 10ms/step
# 2152/2152 - 14s - loss: 7.2708e-04 - val_loss: 7.2527e-04 - 14s/epoch - 7ms/step
# Epoch 42/100
# Mean PSNR for epoch: 31.39
# 2152/2152 - 14s - loss: 7.2638e-04 - val_loss: 7.2492e-04 - 14s/epoch - 6ms/step
# Epoch 43/100
# Mean PSNR for epoch: 31.39
# 2152/2152 - 14s - loss: 7.2574e-04 - val_loss: 7.2548e-04 - 14s/epoch - 6ms/step
# Epoch 44/100
# Mean PSNR for epoch: 31.41
# 2152/2152 - 13s - loss: 7.2530e-04 - val_loss: 7.2180e-04 - 13s/epoch - 6ms/step
# Epoch 45/100
# Mean PSNR for epoch: 31.41
# 2152/2152 - 13s - loss: 7.2467e-04 - val_loss: 7.2178e-04 - 13s/epoch - 6ms/step
# Epoch 46/100
# Mean PSNR for epoch: 31.41
# 2152/2152 - 13s - loss: 7.2395e-04 - val_loss: 7.2169e-04 - 13s/epoch - 6ms/step
# Epoch 47/100
# Mean PSNR for epoch: 31.41
# 2152/2152 - 13s - loss: 7.2329e-04 - val_loss: 7.2184e-04 - 13s/epoch - 6ms/step
# Epoch 48/100
# Mean PSNR for epoch: 31.42
# 2152/2152 - 14s - loss: 7.2279e-04 - val_loss: 7.2017e-04 - 14s/epoch - 6ms/step
# Epoch 49/100
# Mean PSNR for epoch: 31.41
# 2152/2152 - 13s - loss: 7.2224e-04 - val_loss: 7.2093e-04 - 13s/epoch - 6ms/step
# Epoch 50/100
# Mean PSNR for epoch: 31.43
# 2152/2152 - 13s - loss: 7.2157e-04 - val_loss: 7.1846e-04 - 13s/epoch - 6ms/step
# Epoch 51/100
# Mean PSNR for epoch: 31.41
# 2152/2152 - 13s - loss: 7.2103e-04 - val_loss: 7.2142e-04 - 13s/epoch - 6ms/step
# Epoch 52/100
# Mean PSNR for epoch: 31.41
# 2152/2152 - 13s - loss: 7.2042e-04 - val_loss: 7.2200e-04 - 13s/epoch - 6ms/step
# Epoch 53/100
# Mean PSNR for epoch: 31.42
# 2152/2152 - 13s - loss: 7.1992e-04 - val_loss: 7.2045e-04 - 13s/epoch - 6ms/step
# Epoch 54/100
# Mean PSNR for epoch: 31.42
# 2152/2152 - 14s - loss: 7.1947e-04 - val_loss: 7.1913e-04 - 14s/epoch - 6ms/step
# Epoch 55/100
# Mean PSNR for epoch: 31.42
# 2152/2152 - 14s - loss: 7.1903e-04 - val_loss: 7.1875e-04 - 14s/epoch - 6ms/step
# Epoch 56/100
# Mean PSNR for epoch: 31.44
# 2152/2152 - 13s - loss: 7.1865e-04 - val_loss: 7.1658e-04 - 13s/epoch - 6ms/step
# Epoch 57/100
# Mean PSNR for epoch: 31.43
# 2152/2152 - 13s - loss: 7.1837e-04 - val_loss: 7.1722e-04 - 13s/epoch - 6ms/step
# Epoch 58/100
# Mean PSNR for epoch: 31.43
# 2152/2152 - 13s - loss: 7.1793e-04 - val_loss: 7.1808e-04 - 13s/epoch - 6ms/step
# Epoch 59/100
# Mean PSNR for epoch: 31.40
# 2152/2152 - 13s - loss: 7.1774e-04 - val_loss: 7.2346e-04 - 13s/epoch - 6ms/step
# Epoch 60/100
# Mean PSNR for epoch: 31.45
# 2152/2152 - 13s - loss: 7.1750e-04 - val_loss: 7.1544e-04 - 13s/epoch - 6ms/step
# Epoch 61/100
# Mean PSNR for epoch: 31.43
# 1/1 [==============================] - 0s 10ms/step
# 2152/2152 - 14s - loss: 7.1706e-04 - val_loss: 7.1741e-04 - 14s/epoch - 6ms/step
# Epoch 62/100
# Mean PSNR for epoch: 31.43
# 2152/2152 - 13s - loss: 7.1663e-04 - val_loss: 7.1827e-04 - 13s/epoch - 6ms/step
# Epoch 63/100
# Mean PSNR for epoch: 31.44
# 2152/2152 - 13s - loss: 7.1635e-04 - val_loss: 7.1668e-04 - 13s/epoch - 6ms/step
# Epoch 64/100
# Mean PSNR for epoch: 31.44
# 2152/2152 - 14s - loss: 7.1614e-04 - val_loss: 7.1626e-04 - 14s/epoch - 6ms/step
# Epoch 65/100
# Mean PSNR for epoch: 31.45
# 2152/2152 - 13s - loss: 7.1589e-04 - val_loss: 7.1464e-04 - 13s/epoch - 6ms/step
# Epoch 66/100
# Mean PSNR for epoch: 31.46
# 2152/2152 - 13s - loss: 7.1554e-04 - val_loss: 7.1249e-04 - 13s/epoch - 6ms/step
# Epoch 67/100
# Mean PSNR for epoch: 31.45
# 2152/2152 - 14s - loss: 7.1584e-04 - val_loss: 7.1492e-04 - 14s/epoch - 7ms/step
# Epoch 68/100
# Mean PSNR for epoch: 31.46
# 2152/2152 - 14s - loss: 7.1475e-04 - val_loss: 7.1230e-04 - 14s/epoch - 7ms/step
# Epoch 69/100
# Mean PSNR for epoch: 31.46
# 2152/2152 - 15s - loss: 7.1477e-04 - val_loss: 7.1329e-04 - 15s/epoch - 7ms/step
# Epoch 70/100
# Mean PSNR for epoch: 31.46
# 2152/2152 - 14s - loss: 7.1480e-04 - val_loss: 7.1261e-04 - 14s/epoch - 7ms/step
# Epoch 71/100
# Mean PSNR for epoch: 31.46
# 2152/2152 - 14s - loss: 7.1422e-04 - val_loss: 7.1359e-04 - 14s/epoch - 6ms/step
# Epoch 72/100
# Mean PSNR for epoch: 31.46
# 2152/2152 - 14s - loss: 7.1421e-04 - val_loss: 7.1400e-04 - 14s/epoch - 6ms/step
# Epoch 73/100
# Mean PSNR for epoch: 31.47
# 2152/2152 - 13s - loss: 7.1403e-04 - val_loss: 7.1241e-04 - 13s/epoch - 6ms/step
# Epoch 74/100
# Mean PSNR for epoch: 31.46
# 2152/2152 - 13s - loss: 7.1360e-04 - val_loss: 7.1367e-04 - 13s/epoch - 6ms/step
# Epoch 75/100
# Mean PSNR for epoch: 31.47
# 2152/2152 - 13s - loss: 7.1339e-04 - val_loss: 7.1230e-04 - 13s/epoch - 6ms/step
# Epoch 76/100
# Mean PSNR for epoch: 31.46
# 2152/2152 - 13s - loss: 7.1327e-04 - val_loss: 7.1264e-04 - 13s/epoch - 6ms/step
# Epoch 77/100
# Mean PSNR for epoch: 31.47
# 2152/2152 - 13s - loss: 7.1316e-04 - val_loss: 7.1128e-04 - 13s/epoch - 6ms/step
# Epoch 78/100
# Mean PSNR for epoch: 31.48
# 2152/2152 - 13s - loss: 7.1295e-04 - val_loss: 7.1186e-04 - 13s/epoch - 6ms/step
# Epoch 79/100
# Mean PSNR for epoch: 31.46
# 2152/2152 - 13s - loss: 7.1268e-04 - val_loss: 7.1305e-04 - 13s/epoch - 6ms/step
# Epoch 80/100
# Mean PSNR for epoch: 31.47
# 2152/2152 - 13s - loss: 7.1256e-04 - val_loss: 7.1162e-04 - 13s/epoch - 6ms/step
# Epoch 81/100
# Mean PSNR for epoch: 31.46
# 1/1 [==============================] - 0s 10ms/step
# 2152/2152 - 14s - loss: 7.1246e-04 - val_loss: 7.1213e-04 - 14s/epoch - 6ms/step
# Epoch 82/100
# Mean PSNR for epoch: 31.48
# 2152/2152 - 13s - loss: 7.1238e-04 - val_loss: 7.0958e-04 - 13s/epoch - 6ms/step
# Epoch 83/100
# Mean PSNR for epoch: 31.45
# 2152/2152 - 14s - loss: 7.1203e-04 - val_loss: 7.1502e-04 - 14s/epoch - 6ms/step
# Epoch 84/100
# Mean PSNR for epoch: 31.47
# 2152/2152 - 14s - loss: 7.1214e-04 - val_loss: 7.1186e-04 - 14s/epoch - 7ms/step
# Epoch 85/100
# Mean PSNR for epoch: 31.47
# 2152/2152 - 14s - loss: 7.1204e-04 - val_loss: 7.1112e-04 - 14s/epoch - 7ms/step
# Epoch 86/100
# Mean PSNR for epoch: 31.48
# 2152/2152 - 14s - loss: 7.1148e-04 - val_loss: 7.1025e-04 - 14s/epoch - 7ms/step
# Epoch 87/100
# Mean PSNR for epoch: 31.47
# 2152/2152 - 14s - loss: 7.1182e-04 - val_loss: 7.1084e-04 - 14s/epoch - 6ms/step
# Epoch 88/100
# Mean PSNR for epoch: 31.46
# 2152/2152 - 14s - loss: 7.1139e-04 - val_loss: 7.1400e-04 - 14s/epoch - 7ms/step
# Epoch 89/100
# Mean PSNR for epoch: 31.39
# 2152/2152 - 15s - loss: 7.1147e-04 - val_loss: 7.2406e-04 - 15s/epoch - 7ms/step
# Epoch 90/100
# Mean PSNR for epoch: 31.47
# 2152/2152 - 14s - loss: 7.1109e-04 - val_loss: 7.1123e-04 - 14s/epoch - 6ms/step
# Epoch 91/100
# Mean PSNR for epoch: 31.48
# 2152/2152 - 14s - loss: 7.1109e-04 - val_loss: 7.1051e-04 - 14s/epoch - 6ms/step
# Epoch 92/100
# Mean PSNR for epoch: 31.47
# 2152/2152 - 14s - loss: 7.1105e-04 - val_loss: 7.1078e-04 - 14s/epoch - 6ms/step
# Epoch 93/100
# Mean PSNR for epoch: 31.49
# 2152/2152 - 15s - loss: 7.1089e-04 - val_loss: 7.0937e-04 - 15s/epoch - 7ms/step
# Epoch 94/100
# Mean PSNR for epoch: 31.47
# 2152/2152 - 14s - loss: 7.1061e-04 - val_loss: 7.1196e-04 - 14s/epoch - 7ms/step
# Epoch 95/100
# Mean PSNR for epoch: 31.48
# 2152/2152 - 14s - loss: 7.1063e-04 - val_loss: 7.0905e-04 - 14s/epoch - 7ms/step
# Epoch 96/100
# Mean PSNR for epoch: 31.48
# 2152/2152 - 14s - loss: 7.1052e-04 - val_loss: 7.1053e-04 - 14s/epoch - 7ms/step
# Epoch 97/100
# Mean PSNR for epoch: 31.48
# 2152/2152 - 14s - loss: 7.1050e-04 - val_loss: 7.0992e-04 - 14s/epoch - 7ms/step
# Epoch 98/100
# Mean PSNR for epoch: 31.49
# 2152/2152 - 14s - loss: 7.1022e-04 - val_loss: 7.0887e-04 - 14s/epoch - 7ms/step
# Epoch 99/100
# Mean PSNR for epoch: 31.49
# 2152/2152 - 14s - loss: 7.1041e-04 - val_loss: 7.0782e-04 - 14s/epoch - 6ms/step
# Epoch 100/100
# Mean PSNR for epoch: 31.48
# 2152/2152 - 14s - loss: 7.1009e-04 - val_loss: 7.0911e-04 - 14s/epoch - 7ms/step

# %%
total_bicubic_psnr = 0.0
total_test_psnr = 0.0

for index, test_img_path in enumerate(test_img_paths[50:60]):
    img = load_img(test_img_path)
    lowres_input = get_lowres_image(img, upscale_factor)
    w = lowres_input.size[0] * upscale_factor
    h = lowres_input.size[1] * upscale_factor
    highres_img = img.resize((w, h))
    prediction = upscale_image(model, lowres_input)
    lowres_img = lowres_input.resize((w, h))
    lowres_img_arr = img_to_array(lowres_img)
    highres_img_arr = img_to_array(highres_img)
    predict_img_arr = img_to_array(prediction)
    bicubic_psnr = tf.image.psnr(lowres_img_arr, highres_img_arr, max_val=255)
    test_psnr = tf.image.psnr(predict_img_arr, highres_img_arr, max_val=255)

    total_bicubic_psnr += bicubic_psnr
    total_test_psnr += test_psnr

    print(
        "PSNR of low resolution image and high resolution image is %.4f" % bicubic_psnr
    )
    print("PSNR of predict and high resolution is %.4f" % test_psnr)
    plot_results(lowres_img, index, "lowres")
    plot_results(highres_img, index, "highres")
    plot_results(prediction, index, "prediction")

print("Avg. PSNR of lowres images is %.4f" % (total_bicubic_psnr / 10))
print("Avg. PSNR of reconstructions is %.4f" % (total_test_psnr / 10))
# Out:
# 1/1 [==============================] - 0s 11ms/step
# PSNR of low resolution image and high resolution image is 25.3126
# PSNR of predict and high resolution is 27.2908
# /tmp/ipykernel_41296/64990585.py:41: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   PIL.Image.BICUBIC,
# /tmp/ipykernel_41296/64990585.py:62: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   out_img_cb = cb.resize(out_img_y.size, PIL.Image.BICUBIC)
# /tmp/ipykernel_41296/64990585.py:63: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   out_img_cr = cr.resize(out_img_y.size, PIL.Image.BICUBIC)
# 1/1 [==============================] - 0s 11ms/step
# PSNR of low resolution image and high resolution image is 25.7794
# PSNR of predict and high resolution is 27.8066
# 1/1 [==============================] - 0s 11ms/step
# PSNR of low resolution image and high resolution image is 25.1511
# PSNR of predict and high resolution is 27.0479
# 1/1 [==============================] - 0s 14ms/step
# PSNR of low resolution image and high resolution image is 25.3360
# PSNR of predict and high resolution is 27.2333
# 1/1 [==============================] - 0s 12ms/step
# PSNR of low resolution image and high resolution image is 25.5713
# PSNR of predict and high resolution is 27.2683
# 1/1 [==============================] - 0s 13ms/step
# PSNR of low resolution image and high resolution image is 25.6523
# PSNR of predict and high resolution is 27.3836
# 1/1 [==============================] - 0s 12ms/step
# PSNR of low resolution image and high resolution image is 25.4096
# PSNR of predict and high resolution is 27.1014
# 1/1 [==============================] - 0s 11ms/step
# PSNR of low resolution image and high resolution image is 25.4071
# PSNR of predict and high resolution is 27.2092
# 1/1 [==============================] - 0s 11ms/step
# PSNR of low resolution image and high resolution image is 25.0772
# PSNR of predict and high resolution is 26.9468
# 1/1 [==============================] - 0s 11ms/step
# PSNR of low resolution image and high resolution image is 25.2648
# PSNR of predict and high resolution is 27.2234
# Avg. PSNR of lowres images is 25.3961
# Avg. PSNR of reconstructions is 27.2511
